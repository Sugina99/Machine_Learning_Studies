# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %%
#data
boston = load_boston()
boston_df = pd.DataFrame(boston.data,columns=boston.feature_names)
boston_df['Price']= boston.target
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
# value of X and y
X = boston_df.drop(['Price'],axis=1)
y= boston_df['Price']

# %%
# Data Splitting and Scaling
#split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
# fitting
dt_regressor = DecisionTreeRegressor()
dt_regressor.fit(X_train,y_train)

score = dt_regressor.score(X_train,y_train)
print("R-squared Train  :", score)

score = dt_regressor.score(X_test, y_test)
print("R-squared Test  :", score)

y_pred = dt_regressor.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 1.0
# R-squared Test  : 0.8459718790922643
# MSE : 14.11736842105263
# RMSE : 3.757308667258072

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dt_regressor,filled=True,class_names=True)
plt.show()

# %%
dt_regressor = DecisionTreeRegressor(max_depth=3)
dt_regressor.fit(X_train,y_train)

score = dt_regressor.score(X_train,y_train)
print("R-squared Train  :", score)

score = dt_regressor.score(X_test, y_test)
print("R-squared Test  :", score)

y_pred = dt_regressor.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 0.7997484827406776
# R-squared Test  : 0.8064580887242153
# MSE : 17.738984610684234
# RMSE : 4.211767397504786

# %%
# better is max_depth=4
dt_regressor = DecisionTreeRegressor(max_depth=4)
dt_regressor.fit(X_train,y_train)

score = dt_regressor.score(X_train,y_train)
print("R-squared Train  :", score)

score = dt_regressor.score(X_test, y_test)
print("R-squared Test  :", score)

y_pred = dt_regressor.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 0.8857388736713648
# R-squared Test  : 0.8646893116543823
# MSE : 12.40183173970917
# RMSE : 3.521623452288613

# %%
dt_regressor = DecisionTreeRegressor(max_depth=5)
dt_regressor.fit(X_train,y_train)

score = dt_regressor.score(X_train,y_train)
print("R-squared Train  :", score)

score = dt_regressor.score(X_test, y_test)
print("R-squared Test  :", score)

y_pred = dt_regressor.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 0.9224660093061451
# R-squared Test  : 0.7540926611414029
# MSE : 22.538511017653384
# RMSE : 4.747474172405089

# %%
dt_regressor = DecisionTreeRegressor(max_depth=6)
dt_regressor.fit(X_train,y_train)

score = dt_regressor.score(X_train,y_train)
print("R-squared Train  :", score)

score = dt_regressor.score(X_test, y_test)
print("R-squared Test  :", score)

y_pred = dt_regressor.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 0.9485651664023145
# R-squared Test  : 0.7989919861113152
# MSE : 18.42328641631901
# RMSE : 4.292235596553271

# %%
dt_regressor = DecisionTreeRegressor(max_depth=7)
dt_regressor.fit(X_train,y_train)

score = dt_regressor.score(X_train,y_train)
print("R-squared Train  :", score)

score = dt_regressor.score(X_test, y_test)
print("R-squared Test  :", score)

y_pred = dt_regressor.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 0.9723580808024771
# R-squared Test  : 0.8320798224484348
# MSE : 15.390637747531992
# RMSE : 3.9230903312990373

# %%
dt_regressor = DecisionTreeRegressor(max_depth=8)
dt_regressor.fit(X_train,y_train)

score = dt_regressor.score(X_train,y_train)
print("R-squared Train  :", score)

score = dt_regressor.score(X_test, y_test)
print("R-squared Test  :", score)

y_pred = dt_regressor.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 0.9855535125251033
# R-squared Test  : 0.8459142461775647
# MSE : 14.122650736289607
# RMSE : 3.7580115402017604

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dt_regressor,filled=True,class_names=True)
plt.show()
