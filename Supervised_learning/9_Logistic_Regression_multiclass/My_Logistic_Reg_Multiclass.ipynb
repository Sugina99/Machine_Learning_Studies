# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
warnings.filterwarnings('ignore')

# %%
# load data
data=pd.read_csv("winequality.csv",sep=';')

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
data.shape
# Out:
# (4898, 12)

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.600000          0.333250     0.336000        6.392500
# 4             7.129448          0.381227     0.304233        4.628221
# 5             6.933974          0.302011     0.337653        7.334969
# 6             6.837671          0.260564     0.338025        6.441606
# 7             6.734716          0.262767     0.325625        5.186477
# 8             6.657143          0.277400     0.326514        5.671429
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.054300            53.325000            170.600000  0.994884
# 4         0.050098            23.358896            125.279141  0.994277
# 5         0.051546            36.432052            150.904598  0.995263
# 6         0.045217            35.650591            137.047316  0.993961
# ...

# %%
cor_columns=abs(data.corr()['quality'])

# %%
cor_columns[cor_columns<0.1]
# Out:
# citric acid            0.009209
# residual sugar         0.097577
# free sulfur dioxide    0.008158
# pH                     0.099427
# sulphates              0.053678
# Name: quality, dtype: float64

# %%
low_cor=cor_columns[cor_columns<0.1].index

# %%
data.drop(low_cor,axis=1,inplace=True)

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  chlorides  total sulfur dioxide  density  \
# 0            7.0              0.27      0.045                 170.0   1.0010
# 1            6.3              0.30      0.049                 132.0   0.9940
# 2            8.1              0.28      0.050                  97.0   0.9951
# 3            7.2              0.23      0.058                 186.0   0.9956
# 4            7.2              0.23      0.058                 186.0   0.9956
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
X=data.drop(['quality'],axis=1)

# %%
X
# Out:
#       fixed acidity  volatile acidity  chlorides  total sulfur dioxide  \
# 0               7.0              0.27      0.045                 170.0
# 1               6.3              0.30      0.049                 132.0
# 2               8.1              0.28      0.050                  97.0
# 3               7.2              0.23      0.058                 186.0
# 4               7.2              0.23      0.058                 186.0
# ...             ...               ...        ...                   ...
# 4893            6.2              0.21      0.039                  92.0
# 4894            6.6              0.32      0.047                 168.0
# 4895            6.5              0.24      0.041                 111.0
# 4896            5.5              0.29      0.022                 110.0
# 4897            6.0              0.21      0.020                  98.0
#
#       density  alcohol
# 0     1.00100      8.8
# 1     0.99400      9.5
# 2     0.99510     10.1
# ...

# %%
y=data['quality']

# %%
y
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
MM=MinMaxScaler()
actual_df=pd.DataFrame(MM.fit_transform(X))
actual_df.columns=[X.columns]

# %%
actual_df
# Out:
#      fixed acidity volatile acidity chlorides total sulfur dioxide   density  \
# 0         0.307692         0.186275  0.106825             0.373550  0.267785
# 1         0.240385         0.215686  0.118694             0.285383  0.132832
# 2         0.413462         0.196078  0.121662             0.204176  0.154039
# 3         0.326923         0.147059  0.145401             0.410673  0.163678
# 4         0.326923         0.147059  0.145401             0.410673  0.163678
# ...            ...              ...       ...                  ...       ...
# 4893      0.230769         0.127451  0.089021             0.192575  0.077694
# 4894      0.269231         0.235294  0.112760             0.368910  0.150183
# 4895      0.259615         0.156863  0.094955             0.236659  0.104685
# 4896      0.163462         0.205882  0.038576             0.234339  0.030461
# 4897      0.211538         0.127451  0.032641             0.206497  0.044342
#
#        alcohol
# 0     0.129032
# ...

# %%
actual_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   (fixed acidity,)         4898 non-null   float64
#  1   (volatile acidity,)      4898 non-null   float64
#  2   (chlorides,)             4898 non-null   float64
#  3   (total sulfur dioxide,)  4898 non-null   float64
#  4   (density,)               4898 non-null   float64
#  5   (alcohol,)               4898 non-null   float64
# dtypes: float64(6)
# memory usage: 229.7 KB

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=42)

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  chlorides  total sulfur dioxide  \
# 736             6.6              0.25      0.052                 183.0
# 1620            7.8              0.26      0.027                  87.0
# 336             6.3              0.23      0.036                 105.0
# 2302            6.0              0.26      0.055                 194.0
# 2673            7.9              0.37      0.037                  24.0
# ...             ...               ...        ...                   ...
# 4426            6.2              0.21      0.047                 123.0
# 466             7.0              0.14      0.039                 141.0
# 3092            7.6              0.27      0.043                 152.0
# 3772            6.3              0.24      0.035                 134.0
# 860             8.1              0.27      0.030                 103.0
#
#       density  alcohol
# 736   0.99800      9.1
# 1620  0.99190     11.3
# 336   0.99100     11.2
# ...

# %%
X_test
# Out:
#       fixed acidity  volatile acidity  chlorides  total sulfur dioxide  \
# 4656            6.0              0.29      0.048                 149.0
# 3659            5.4              0.53      0.036                 128.0
# 907             7.1              0.25      0.036                 124.0
# 4352            7.3              0.28      0.054                 148.0
# 3271            6.5              0.32      0.044                  91.0
# ...             ...               ...        ...                   ...
# 4235            6.4              0.29      0.040                 116.0
# 4588            6.4              0.30      0.050                 137.0
# 3377            7.0              0.40      0.050                 189.0
# 1503            6.8              0.36      0.039                 124.0
# 1971            6.3              0.41      0.030                 164.0
#
#       density    alcohol
# 4656  0.99370  10.966667
# 3659  0.98856  13.200000
# 907   0.99080  12.200000
# ...

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
# 
lr.predict(X_test)

# %%
lr.score(X_train,y_train)
# Out:
# 0.4763710618436406

# %%
lr.score(X_test,y_test)
# Out:
# 0.4816326530612245
