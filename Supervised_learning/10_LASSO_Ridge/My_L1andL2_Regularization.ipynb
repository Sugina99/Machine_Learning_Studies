# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.model_selection import train_test_split

# %%
# load data
data=pd.read_csv("Melbourne_housing_FULL.csv")

# %%
data.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
data.shape
# Out:
# (34857, 21)

# %%
data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
data.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
# do eda later..just testing lasso and ridge regression..so taking few cols only

# %%
data.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
# lets use limited columns which makes more sence for serving our purpose
cols_to_use=['Suburb','Rooms','Type','Method','SellerG','Regionname','Propertycount','Distance','CouncilArea','Bedroom2','Bathroom','Car','Landsize','Price','BuildingArea']

# %%
data=data[cols_to_use]

# %%
data.head()
# Out:
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 0  Abbotsford      2    h     SS  Jellis  Northern Metropolitan
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 2  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 3  Abbotsford      3    u     VB  Rounds  Northern Metropolitan
# 4  Abbotsford      3    h     SP  Biggin  Northern Metropolitan
#
#    Propertycount  Distance         CouncilArea  Bedroom2  Bathroom  Car  \
# 0         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 1         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 2         4019.0       2.5  Yarra City Council       2.0       1.0  0.0
# 3         4019.0       2.5  Yarra City Council       3.0       2.0  1.0
# 4         4019.0       2.5  Yarra City Council       3.0       2.0  0.0
#
#    Landsize      Price  BuildingArea
# 0     126.0        NaN           NaN
# 1     202.0  1480000.0           NaN
# ...

# %%
data.shape
# Out:
# (34857, 15)

# %%
data.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        3
# Distance             1
# CouncilArea          3
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# Price             7610
# BuildingArea     21115
# dtype: int64

# %%
# fill missing value with mode and median
data['Regionname']=data['Regionname'].fillna(data['Regionname'].mode()[0])
data['CouncilArea']=data['CouncilArea'].fillna(data['CouncilArea'].mode()[0])

data['Propertycount']=data['Propertycount'].fillna(data['Propertycount'].median())
data['BuildingArea']=data['BuildingArea'].fillna(data['BuildingArea'].median())

data['Distance']=data['Distance'].fillna(data['Distance'].median())
data['Bedroom2']=data['Bedroom2'].fillna(data['Bedroom2'].mode()[0])
data['Bathroom']=data['Bathroom'].fillna(data['Bathroom'].mode()[0])
data['Car']=data['Car'].fillna(data['Car'].mode()[0])
data['Landsize']=data['Landsize'].fillna(data['Landsize'].median())

# %%
data.isna().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          0
# Propertycount       0
# Distance            0
# CouncilArea         0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# Price            7610
# BuildingArea        0
# dtype: int64

# %%
# dependend varible 'Price' has missing values there fore we removing the column.
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (27247, 15)

# %%
data.head()
# Out:
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 2  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 4  Abbotsford      3    h     SP  Biggin  Northern Metropolitan
# 5  Abbotsford      3    h     PI  Biggin  Northern Metropolitan
# 6  Abbotsford      4    h     VB  Nelson  Northern Metropolitan
#
#    Propertycount  Distance         CouncilArea  Bedroom2  Bathroom  Car  \
# 1         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 2         4019.0       2.5  Yarra City Council       2.0       1.0  0.0
# 4         4019.0       2.5  Yarra City Council       3.0       2.0  0.0
# 5         4019.0       2.5  Yarra City Council       3.0       2.0  1.0
# 6         4019.0       2.5  Yarra City Council       3.0       1.0  2.0
#
#    Landsize      Price  BuildingArea
# 1     202.0  1480000.0         136.0
# 2     156.0  1035000.0          79.0
# ...

# %%
# encoding :- onehot encoding
data=pd.get_dummies(data,drop_first=True)
data.head()
# Out:
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1      2         4019.0       2.5       2.0       1.0  1.0     202.0
# 2      2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4      3         4019.0       2.5       3.0       2.0  0.0     134.0
# 5      3         4019.0       2.5       3.0       2.0  1.0      94.0
# 6      4         4019.0       2.5       3.0       1.0  2.0     120.0
#
#        Price  BuildingArea  Suburb_Aberfeldie  ...  \
# 1  1480000.0         136.0                  0  ...
# 2  1035000.0          79.0                  0  ...
# 4  1465000.0         150.0                  0  ...
# 5   850000.0         136.0                  0  ...
# 6  1600000.0         142.0                  0  ...
#
#    CouncilArea_Moorabool Shire Council  CouncilArea_Moreland City Council  \
# 1                                    0                                  0
# 2                                    0                                  0
# ...

# %%
X=data.drop('Price',axis=1)
y=data['Price']

# %%
X
# Out:
#        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1          2         4019.0       2.5       2.0       1.0  1.0     202.0
# 2          2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4          3         4019.0       2.5       3.0       2.0  0.0     134.0
# 5          3         4019.0       2.5       3.0       2.0  1.0      94.0
# 6          4         4019.0       2.5       3.0       1.0  2.0     120.0
# ...      ...            ...       ...       ...       ...  ...       ...
# 34852      4         6543.0       6.3       4.0       1.0  3.0     593.0
# 34853      2         6543.0       6.3       2.0       2.0  1.0      98.0
# 34854      2         6543.0       6.3       2.0       1.0  2.0     220.0
# 34855      3         6543.0       6.3       3.0       1.0  2.0     521.0
# 34856      2         6543.0       6.3       2.0       1.0  0.0     250.0
#
#        BuildingArea  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=21)

# %%
scaler=StandardScaler()
scaler.fit_transform(X_train)
# Out:
# array([[ 0.01491407, -0.25097293, -0.56097531, ..., -0.1355294 ,
#         -0.18694069, -0.05278908],
#        [-1.0308251 , -0.3063638 , -0.75111958, ..., -0.1355294 ,
#         -0.18694069, -0.05278908],
#        [-1.0308251 , -0.65133819, -0.57560179, ..., -0.1355294 ,
#         -0.18694069, -0.05278908],
#        ...,
#        [ 1.06065323, -0.02874473, -0.20993972, ..., -0.1355294 ,
#         -0.18694069, -0.05278908],
#        [ 0.01491407, -1.12105282,  0.47750496, ..., -0.1355294 ,
#         -0.18694069, -0.05278908],
#        [-1.0308251 ,  0.02265801, -0.9851433 , ..., -0.1355294 ,
#         -0.18694069, -0.05278908]])

# %%
actual_df=pd.DataFrame(scaler.fit_transform(X_train))

# %%
actual_df.columns=X.columns

# %%
actual_df
# Out:
#           Rooms  Propertycount  Distance  Bedroom2  Bathroom       Car  \
# 0      0.014914      -0.250973 -0.560975 -1.236976 -0.678696  0.242402
# 1     -1.030825      -0.306364 -0.751120 -1.236976 -0.678696 -0.898538
# 2     -1.030825      -0.651338 -0.575602 -1.236976 -0.678696 -0.898538
# 3      0.014914      -0.303705 -1.131408 -0.038033  0.845752  0.242402
# 4      1.060653      -0.959533 -0.239193 -0.038033 -0.678696  0.242402
# ...         ...            ...       ...       ...       ...       ...
# 19067  0.014914      -0.393881  0.784661 -0.038033 -0.678696  0.242402
# 19068 -1.030825      -1.498597  0.462878 -0.038033 -0.678696  0.242402
# 19069  1.060653      -0.028745 -0.209940 -0.038033 -0.678696  0.242402
# 19070  0.014914      -1.121053  0.477505 -0.038033 -0.678696  2.524281
# 19071 -1.030825       0.022658 -0.985143 -1.236976  0.845752 -0.898538
#
#        Landsize  BuildingArea  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# ...

# %%
##### using Ridge Regression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([ 983815.09077244, 1381302.90080266, 1372861.89170039, ...,
#        1587596.39969353, 2084476.56291462, 1320589.57199887])

# %%
train_accuracy=lr.score(X_train,y_train)

# %%
test_accuracy=lr.score(X_test,y_test)

# %%
print(f"train accuracy is: {train_accuracy}")
print(f"test accuracy is: {test_accuracy}")
# Out:
# train accuracy is: 0.682598056951955
# test accuracy is: 0.6629137513899394

# %%
# alpha=50
ridge_reg=Ridge(alpha=50) #alpha is lambda value
ridge_reg.fit(X_train,y_train)
# Out:
# Ridge(alpha=50)

# %%
ridge_reg.predict(X_test)
# Out:
# array([ 963386.84677813, 1363469.49224224, 1371513.00951765, ...,
#        1581120.91376659, 1958998.57934053, 1338540.22790819])

# %%
ridge_reg.score(X_train,y_train)
# Out:
# 0.6655512674240536

# %%
ridge_reg.score(X_test,y_test)
# Out:
# 0.6532606503147119

# %%
# alpha=10
ridge_reg=Ridge(alpha=10) #alpha is lambda value
ridge_reg.fit(X_train,y_train)
# Out:
# Ridge(alpha=10)

# %%
ridge_reg.score(X_train,y_train)
# Out:
# 0.6773013194817566

# %%
ridge_reg.score(X_test,y_test)
# Out:
# 0.664140460665021

# %%
ridge_reg=Ridge(alpha=0.1) #alpha is lambda value
ridge_reg.fit(X_train,y_train)
train_accuracy=ridge_reg.score(X_train,y_train)
test_accuracy=ridge_reg.score(X_test,y_test)
print(f"train_accuracy = {train_accuracy}")
print(f"test_accuracy = {test_accuracy}")
# Out:
# train_accuracy = 0.682565207983403
# test_accuracy = 0.6635674925755397

# %%
##### using LASSO Regression
lasso_reg=Lasso(alpha=50)
lasso_reg.fit(X_train,y_train)
# Out:
# Lasso(alpha=50)

# %%
train_accuracy=lasso_reg.score(X_train,y_train)
test_accuracy=lasso_reg.score(X_test,y_test)
print(f"train_accuracy = {train_accuracy}")
print(f"test_accuracy = {test_accuracy}")
# Out:
# train_accuracy = 0.678251227983256
# test_accuracy = 0.6648807572789179

# %%
lasso_reg=Lasso(alpha=0.1)
lasso_reg.fit(X_train,y_train)
train_accuracy=lasso_reg.score(X_train,y_train)
test_accuracy=lasso_reg.score(X_test,y_test)
print(f"train_accuracy = {train_accuracy}")
print(f"test_accuracy = {test_accuracy}")
# Out:
# train_accuracy = 0.6825912320803349
# test_accuracy = 0.663003440935081

# %%
from sklearn.feature_selection import SelectFromModel

# %%
model=SelectFromModel(lasso_reg)

# %%
model.fit(X_train,y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=50))

# %%
X.head()
# Out:
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1      2         4019.0       2.5       2.0       1.0  1.0     202.0
# 2      2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4      3         4019.0       2.5       3.0       2.0  0.0     134.0
# 5      3         4019.0       2.5       3.0       2.0  1.0      94.0
# 6      4         4019.0       2.5       3.0       1.0  2.0     120.0
#
#    BuildingArea  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# 1         136.0                  0                    0  ...
# 2          79.0                  0                    0  ...
# 4         150.0                  0                    0  ...
# 5         136.0                  0                    0  ...
# 6         142.0                  0                    0  ...
#
#    CouncilArea_Moorabool Shire Council  CouncilArea_Moreland City Council  \
# 1                                    0                                  0
# ...

# %%
X.columns[(model.get_support())]
# Out:
# Index(['Rooms', 'Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'Suburb_Aberfeldie', 'Suburb_Airport West',
#        ...
#        'CouncilArea_Melbourne City Council', 'CouncilArea_Melton City Council',
#        'CouncilArea_Monash City Council',
#        'CouncilArea_Moonee Valley City Council',
#        'CouncilArea_Port Phillip City Council',
#        'CouncilArea_Stonnington City Council',
#        'CouncilArea_Whitehorse City Council',
#        'CouncilArea_Whittlesea City Council',
#        'CouncilArea_Wyndham City Council', 'CouncilArea_Yarra City Council'],
#       dtype='object', length=336)

# %%
selected_features=X.columns[(model.get_support())]

# %%
data.shape[1]
# Out:
# 746

# %%
len(selected_features)
# Out:
# 336

# %%
np.sum(model.estimator_.coef_==0)
# Out:
# 409
